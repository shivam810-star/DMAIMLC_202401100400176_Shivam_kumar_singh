# %%
import tensorflow as tf
import numpy as np
#convert data to numpy arrays
x= np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#define modelusing input layer
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

#compile the modle
model.compile(optimizer='sgd',loss='mean_squared_error')

#train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - loss: 12.7601
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 8.8619
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.1569
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.2800
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9776
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.0738
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.4467
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.0115
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.7094
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4998

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#convert to numpy array
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#define the model
model=Sequential([
    Dense(1,input_shape=(1,))
])

#Compile the model
model.compile(optimizer='sgd',loss='mse')

#train the mpodel
model.fit(x,y,epochs=20)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 66.1370
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 45.9322
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 31.9122
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 22.1838
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 15.4332
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 10.7489
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.4983
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.2425
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.6771
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.5906
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.8365
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.3130
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9495
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6971
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5217
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3998
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3149
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2558
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2146
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1858

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple linear model
model = nn.Linear(1, 1)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Dummy Data
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# Training loop
for epoch in range(10):
    optimizer.zero_grad()

    outputs = model(x)
    loss = criterion(outputs, y)

    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 50.97754669189453
# Epoch 2, Loss: 35.460201263427734
# Epoch 3, Loss: 24.692516326904297
# Epoch 4, Loss: 17.220523834228516
# Epoch 5, Loss: 12.035348892211914
# Epoch 6, Loss: 8.436949729919434
# Epoch 7, Loss: 5.939582347869873
# Epoch 8, Loss: 4.206201076507568
# Epoch 9, Loss: 3.0029382705688477
# Epoch 10, Loss: 2.167513847351074
