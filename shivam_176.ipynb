# %%
X=[0.75,0.65,0.80]
w=[0.4,0.3,0.5]
b=-0.2
y=1
n=0.01
z=0
for i in range(len(X)):
  z+=X[i]*w[i];
net_input=z+b;

if net_input<0:
   y_pred=0;
else:
   y_pred=1;
print(y_pred)
error=y-y_pred;

print("error is ",error)
if error==1:
  for i in range(len(w)):
    w[i]+=n*X[i]
  b+=n*error
for i in range(len(X)):
  z+=w[i]*X[i];
# Out:
# 1
# error is  0
